# %%
import numpy as np

# %%
dataset = np.genfromtxt('ejemplo.csv',
                        delimiter=',',
                        skip_header=1,
                        dtype=float)
dataset
# Out:
# array([5. , 7. , 3. , 1.5])

# %%
dataset = np.genfromtxt('../data/calificaciones.csv',
                        delimiter=',',
                        skip_header=1,
                        dtype=int)
dataset
# Out:
# array([ 5, 10,  9,  3,  7])

# %%
# PROBLEMA NUMPY: si el CSV una columna tiene comillas puede romper el separador
vgsales_europe = np.genfromtxt('../data/vgsales.csv', 
              usecols=(5), dtype=int, skip_header=1, delimiter=',')
vgsales_europe.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 vgsales_europe = np.genfromtxt('../data/vgsales.csv',
#       2               usecols=(5), dtype=int, skip_header=1, delimiter=',')
#       3 vgsales_europe.shape
#
# File c:\dev\curso-ia-2024-04\.curso-ia-2024-04\Lib\site-packages\numpy\lib\npyio.py:2312, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    2310 # Raise an exception ?
#    2311 if invalid_raise:
# -> 2312     raise ValueError(errmsg)
#    2313 # Issue a warning ?
#    2314 else:
#    2315     warnings.warn(errmsg, ConversionWarning, stacklevel=2)
#
# ValueError: Some errors were detected !
# ...

# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
df.tail()
# Out:
#         Rank                                              Name Platform  \
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year     Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 16593  2002.0  Platform       Kemco      0.01      0.00       0.0
# 16594  2003.0   Shooter  Infogrames      0.01      0.00       0.0
# 16595  2008.0    Racing  Activision      0.00      0.00       0.0
# 16596  2010.0    Puzzle    7G//AMES      0.00      0.01       0.0
# 16597  2003.0  Platform     Wanadoo      0.01      0.00       0.0
#
#        Other_Sales  Global_Sales
# 16593          0.0          0.01
# 16594          0.0          0.01
# ...

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.describe(include='all')
# Out:
#                 Rank                         Name Platform          Year  \
# count   16598.000000                        16598    16598  16327.000000
# unique           NaN                        11493       31           NaN
# top              NaN  Need for Speed: Most Wanted       DS           NaN
# freq             NaN                           12     2163           NaN
# mean     8300.605254                          NaN      NaN   2006.406443
# std      4791.853933                          NaN      NaN      5.828981
# min         1.000000                          NaN      NaN   1980.000000
# 25%      4151.250000                          NaN      NaN   2003.000000
# 50%      8300.500000                          NaN      NaN   2007.000000
# 75%     12449.750000                          NaN      NaN   2010.000000
# max     16600.000000                          NaN      NaN   2020.000000
#
#          Genre        Publisher      NA_Sales      EU_Sales      JP_Sales  \
# ...

# %%
df.shape
# Out:
# (16598, 11)

# %%
np.max(df['EU_Sales'].to_numpy())
# Out:
# 29.02

# %%
np.max(df['EU_Sales'])
# Out:
# 29.02

# %%
pd.read_csv('../data/airline_passengers.csv')
# Out:
#        Month  Thousands of Passengers
# 0    1949-01                      112
# 1    1949-02                      118
# 2    1949-03                      132
# 3    1949-04                      129
# 4    1949-05                      121
# ..       ...                      ...
# 139  1960-08                      606
# 140  1960-09                      508
# 141  1960-10                      461
# 142  1960-11                      390
# 143  1960-12                      432
#
# [144 rows x 2 columns]

# %% [markdown]
# ## EJEMPLO RENOMBRAR COLUMNAS EN PANDAS
#
# df.rename

# %%
df = pd.read_csv('pandas_rename.csv')
df.head()
# Out:
#   columna 1   columna 2  columna_3
# 0  Persona1          20        8.7
# 1  Persona2          30        6.5

# %%
df['columna 1']
# Out:
# 0    Persona1
# 1    Persona2
# Name: columna 1, dtype: object

# %%
df = df.rename(columns={'columna 1': 'columna_1'})

# %%
df.head()
# Out:
#   columna_1   columna 2
# 0  Persona1          20
# 1  Persona2          30

# %%
df.columna_1
# Out:
# 0    Persona1
# 1    Persona2
# Name: columna_1, dtype: object

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (2, 3)

# %%
df.dtypes
# Out:
# columna 1      object
#  columna 2      int64
# columna_3     float64
# dtype: object

# %%
df = pd.read_csv('pandas_rename.csv')
df.head()
# Out:
#   columna 1  columna 2  columna_3
# 0  Persona1         20        8.7
# 1  Persona2         30        6.5

# %%
df['columna_3_dto'] = df['columna_3'] * 0.90

# %%
df.head()
# Out:
#   columna 1  columna 2  columna_3  columna_3_dto
# 0  Persona1         20        8.7           7.83
# 1  Persona2         30        6.5           5.85

# %%
df['col2'] = df['columna 2']
df.head()
# Out:
#   columna 1  columna 2  columna_3  columna_3_dto  col2
# 0  Persona1         20        8.7           7.83    20
# 1  Persona2         30        6.5           5.85    30
