# %%
from sklearn.model_selection import train_test_split

df_sample, _ = train_test_split(df, train_size=1200, stratify=df['class'], random_state=21)

df_sample = df.groupby('class', group_keys=False).apply(lambda x: x.sample(frac=1200/len(df), random_state=42))
